# %% [markdown]
# ## 📌 Step 1: Import Required

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot  as plt

# %% [markdown]
# ## 📌 Step 2: Load the Dataset

# %%
df = pd.read_csv(r"C:\Users\zabiz\Downloads\ML_Models\Classification\XGBoost Classification\car_sales_dataset.csv")

# %% [markdown]
# ## 📌 Step 3: View First 5 Rows of Dataset

# %%
df.head()
# Out:
#    CarPrice  Mileage  EngineSize  Horsepower  Age  BrandValue  SellerRating  \
# 0     20795    50536         2.0         194    2           1           1.0
# 1      5860    74504         2.0          84    3           3           1.6
# 2     43158   104214         1.3          82   10           5           3.3
# 3     49732   187220         4.7         187    5           7           4.3
# 4     16284   118936         3.3         309    9           5           1.8
#
#    AdSpend  Warranty  FuelType Transmission Region  Sold
# 0      114         0  Electric    Automatic  South     1
# 1     3228         1    Petrol       Manual  South     1
# 2     1453         1  Electric       Manual  South     0
# 3     3235         1    Hybrid    Automatic  North     0
# 4     2377         0    Petrol    Automatic  North     0

# %% [markdown]
# ## 📌 Step 4: Check Dataset Shape

# %%
df.shape
# Out:
# (5000, 13)

# %% [markdown]
# ## 📌 Step 5: Import Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## 📌 Step 6: Apply Label Encoder

# %%
le = LabelEncoder()
df["FuelType"] = pd.DataFrame(le.fit_transform(df["FuelType"]))
df["Transmission"] = pd.DataFrame(le.fit_transform(df["Transmission"]))
df["Region"] = pd.DataFrame(le.fit_transform(df["Region"]))

# %% [markdown]
# ## 📌 Step 7: Check the data after Label Encoder

# %%
df.head()
# Out:
#    CarPrice  Mileage  EngineSize  Horsepower  Age  BrandValue  SellerRating  \
# 0     20795    50536         2.0         194    2           1           1.0
# 1      5860    74504         2.0          84    3           3           1.6
# 2     43158   104214         1.3          82   10           5           3.3
# 3     49732   187220         4.7         187    5           7           4.3
# 4     16284   118936         3.3         309    9           5           1.8
#
#    AdSpend  Warranty  FuelType  Transmission  Region  Sold
# 0      114         0         1             0       2     1
# 1     3228         1         3             1       2     1
# 2     1453         1         1             1       2     0
# 3     3235         1         2             0       1     0
# 4     2377         0         3             0       1     0

# %% [markdown]
# ## 📌 Step 8: Check Missing Values in Dataset

# %%
df.isnull().sum()
# Out:
# CarPrice        0
# Mileage         0
# EngineSize      0
# Horsepower      0
# Age             0
# BrandValue      0
# SellerRating    0
# AdSpend         0
# Warranty        0
# FuelType        0
# Transmission    0
# Region          0
# Sold            0
# dtype: int64

# %% [markdown]
# ## 📌 Step 9:Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CarPrice      5000 non-null   int64
#  1   Mileage       5000 non-null   int64
#  2   EngineSize    5000 non-null   float64
#  3   Horsepower    5000 non-null   int64
#  4   Age           5000 non-null   int64
#  5   BrandValue    5000 non-null   int64
#  6   SellerRating  5000 non-null   float64
#  7   AdSpend       5000 non-null   int64
#  8   Warranty      5000 non-null   int64
#  9   FuelType      5000 non-null   int64
#  10  Transmission  5000 non-null   int64
#  11  Region        5000 non-null   int64
#  12  Sold          5000 non-null   int64
# dtypes: float64(2), int64(11)
# memory usage: 507.9 KB

# %% [markdown]
# ## 📌 Step 10:Statistical Summary

# %%
df.describe()
# Out:
#            CarPrice        Mileage   EngineSize   Horsepower          Age  \
# count   5000.000000    5000.000000  5000.000000  5000.000000  5000.000000
# mean   27330.371000  101536.327800     2.981640   234.468200     7.434200
# std    12873.343444   55750.308455     1.144656    94.680312     4.044372
# min     5009.000000    5028.000000     1.000000    70.000000     1.000000
# 25%    16128.000000   53027.000000     2.000000   151.750000     4.000000
# 50%    27437.500000  101870.000000     3.000000   234.000000     7.000000
# 75%    38345.250000  149413.750000     4.000000   315.000000    11.000000
# max    49976.000000  199999.000000     5.000000   399.000000    14.000000
#
#         BrandValue  SellerRating      AdSpend     Warranty     FuelType  \
# count  5000.000000   5000.000000  5000.000000  5000.000000  5000.000000
# mean      5.036000      3.036660  2567.909800     0.516000     1.487400
# std       2.552177      1.160036  1398.366145     0.499794     1.118075
# min       1.000000      1.000000   100.000000     0.000000     0.000000
# 25%       3.000000      2.000000  1393.250000     0.000000     0.000000
# 50%       5.000000      3.100000  2561.000000     1.000000     1.000000
# 75%       7.000000      4.000000  3778.000000     1.000000     2.000000
# max       9.000000      5.000000  4999.000000     1.000000     3.000000
#
#        Transmission       Region        Sold
# count    5000.00000  5000.000000  5000.00000
# mean        0.50000     1.472600     0.50000
# std         0.50005     1.117094     0.50005
# min         0.00000     0.000000     0.00000
# 25%         0.00000     0.000000     0.00000
# 50%         0.50000     1.000000     0.50000
# 75%         1.00000     2.000000     1.00000
# max         1.00000     3.000000     1.00000

# %% [markdown]
# ## 📌 Step 11: Boxplot Visualization

# %%
sns.boxplot(data=df,orient='h')
plt.title("check the outlier in the dataset")
plt.show()

# %% [markdown]
# ## 📌 Step 12: Pairplot Visualization

# %%
sns.pairplot(data=df)
plt.title("check the relationship between the columns")
plt.show()

# %% [markdown]
# ## 📌 Step 13: Correlation Heatmap

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap="coolwarm")
plt.title("check the co-relationship between the columns")
plt.show()

# %% [markdown]
# ## 📌 Step 14: Feature and Target Split
# - **X (features):** Sare columns except last (Sold)
# - **y (target):** Only species column

# %%
x = df.iloc[:,:-1]
y = df["Sold"]

# %% [markdown]
# ## 📌 Step 15: Train-Test Split
# - The dataset is divided into **training** and **testing** parts.
# - Typically, **70–80%** of the data is used for training, and **20–30%** is used for testing.

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 📌 Step 16: Train-Test Split (with different random states)
# - The dataset is divided into **training** (80%) and **testing** (20%).
# - Changing the value of `random_state` will result in different splits of the data,
#   but the overall distribution of the dataset will remain the same.

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=19)

# %% [markdown]
# ## 📌 Step 17: Import Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 📌 Step 18: Apply Standard Scaler

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# ## 📌 Step 19: Import XGBoostClassifier
#
# We import the **XGBBoostClassifier** from `catboost`.
# CatBoost is a powerful gradient boosting algorithm that handles categorical and numerical features efficiently.
# It is widely used for classification tasks because of its high accuracy, ability to handle missing values, and
# built-in support for categorical encoding.

# %%
from xgboost import XGBClassifier

# %% [markdown]
# ## 📌 Step 20: XGBoost Classification Model
#
# In this step, we build and train an **XGBoost Classifier** on our dataset.
# XGBoost is a powerful and efficient gradient boosting algorithm, widely used for structured/tabular data.
#
# ### 📌 Model Parameters:
# - `n_estimators=300` → Number of boosting rounds (trees)
# - `max_depth=4` → Maximum depth of each tree
# - `learning_rate=0.1` → Shrinkage step size for each boosting step
# - `subsample=0.8` → Fraction of training samples used per boosting round
# - `colsample_bytree=0.8` → Fraction of features used per tree
# - `reg_lambda=1` → L2 regularization (to avoid overfitting)
# - `random_state=42` → Ensures reproducibility
# - `eval_metric='logloss'` → Evaluation metric for binary classification

# %%
xgbc = XGBClassifier(
    n_estimators=300,
    max_depth=4,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_lambda=1,
    random_state=42,
    eval_metric='logloss'
)
xgbc.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, ...)

# %% [markdown]
# ## 📌 Step 21: Model Accuracy (Train vs Test)
#
# - `adc.score(x_test, y_test)` → Checks the accuracy on the **test dataset**.
# - `adc.score(x_train, y_train)` → Checks the accuracy on the **training dataset**.
# - We multiply by `*100` to convert the values into percentages.
#
# ✔️ **Test and Train values of this model:** `(90.5 , 99.07)`
#
# 👉 This step helps us check whether the model is **overfitting** or not.
# - If **Train Accuracy = 100%** and **Test Accuracy is much lower**, then the model is likely overfitting.
# - Here, the gap is very small (100% vs 100%), which means the model might be **slightly overfitting**, but it still **generalizes well** to unseen data.

# %%
xgbc.score(x_test,y_test)*100,xgbc.score(x_train,y_train)*100
# Out:
# (90.5, 99.075)

# %% [markdown]
# ## 📌 Step 22: Adding Predictions to the Dataset
#
# We can use our trained **XGBoostClassifier** to make predictions on the entire dataset `x` and store the results in a new column.

# %%
df["Prediction"] = xgbc.predict(x)
df.head()
# Out:
#    CarPrice  Mileage  EngineSize  Horsepower  Age  BrandValue  SellerRating  \
# 0     20795    50536         2.0         194    2           1           1.0
# 1      5860    74504         2.0          84    3           3           1.6
# 2     43158   104214         1.3          82   10           5           3.3
# 3     49732   187220         4.7         187    5           7           4.3
# 4     16284   118936         3.3         309    9           5           1.8
#
#    AdSpend  Warranty  FuelType  Transmission  Region  Sold  Prediction
# 0      114         0         1             0       2     1           1
# 1     3228         1         3             1       2     1           1
# 2     1453         1         1             1       2     0           0
# 3     3235         1         2             0       1     0           0
# 4     2377         0         3             0       1     0           0

# %% [markdown]
# ## 📌 Step 23: Making Predictions on Test Data
#
# Once the model is trained, we use it to predict the target variable (`y_test`) from the unseen test features (`x_test`).

# %%
y_pred = xgbc.predict(x_test)

# %% [markdown]
# ## 📌 Step 24: Cross-Validation (Model Stability Check)
#
# - We applied **5-Fold Cross Validation** to evaluate the stability and generalization of our **CatBoost Classifier**.
# - In each fold, the dataset was split into training and testing parts, and accuracy was measured.
#
# ✔️ **Cross Validation Scores (per fold):** `[0.912 0.912 0.928 0.903 0.915]`
# ✔️ **Mean Accuracy:** `≈ 91.4%`
# ✔️ **Standard Deviation:** `≈ 0.8074651695274546`
#
# 👉 Since the scores are **extremely close** across folds with a **very low standard deviation**, this indicates that our CatBoost model is **highly stable, consistent, and generalizes very well** across different data splits.

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_scores = cross_val_score(xgbc, x, y, cv=5, scoring='accuracy')

print("Cross Validation Scores:", cv_scores)
print("Mean Accuracy:", cv_scores.mean()*100)
print("Standard Deviation:", cv_scores.std()*100)
# Out:
# Cross Validation Scores: [0.912 0.912 0.928 0.903 0.915]
# Mean Accuracy: 91.4
# Standard Deviation: 0.8074651695274546

# %% [markdown]
# ## 📌 Step 25: Import Classification Metrics
#
# To evaluate the model’s performance, we import important metrics from `sklearn.metrics`:
#
# - **Confusion Matrix** → To visualize correct vs incorrect predictions
# - **Precision Score** → How precise the model is in positive predictions
# - **Recall Score** → How well the model captures actual positives
# - **F1 Score** → Balance between Precision & Recall

# %%
from sklearn.metrics import f1_score,precision_score,confusion_matrix,recall_score

# %% [markdown]
# ## 📌 Step 26: Precision Score
#
# - **Precision** measures how many of the predicted positive cases are actually positive.
# - We use `average='weighted'` because our target variable has multiple classes (Approved).
# - Multiplying by `100` gives the result in **percentage form**.

# %%
precision = precision_score(y_test, y_pred, average='weighted')*100
print("Precision Score:", precision)
# Out:
# Precision Score: 90.63356493340163

# %% [markdown]
# ## 📌 Step 27: F1 Score
#
# - **F1 Score** is the harmonic mean of **Precision** and **Recall**.
# - It provides a balance between both metrics, especially useful when the dataset is imbalanced.
# - We use `average='weighted'` for multi-class classification.
# - Multiplying by `100` gives the result in **percentage form**.

# %%
f1 = f1_score(y_test, y_pred, average='weighted')*100
print("F1 Score:", f1)
# Out:
# F1 Score: 90.50076950692556

# %% [markdown]
# ## 📌 Step 28: Recall Score
#
# - **Recall** measures how many actual positive cases the model correctly identified.
# - We use `average='weighted'` to handle multiple classes fairly.
# - Multiplying by `100` gives the result in **percentage form**.

# %%
recall = recall_score(y_test, y_pred, average='weighted')*100
print("Recall Score:", recall)
# Out:
# Recall Score: 90.5

# %% [markdown]
# ## 📌 Step 29: Confusion Matrix (Numerical Form)
#
# - A **Confusion Matrix** shows how many predictions were correct vs incorrect for each class.
# - It is especially useful for evaluating classification models.

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[454,  61],
#        [ 34, 451]])

# %% [markdown]
# ## 📌 Step 30: Confusion Matrix Heatmap
#
# - To better **visualize** the confusion matrix, we use a **heatmap**.
# - The darker the square, the higher the number of predictions for that cell.
# - X-axis → Predicted Labels
# - Y-axis → True Labels

# %%
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix Heatmap")
plt.show()

# %% [markdown]
# ## 📌 Step 31: Actual vs Predicted (Graphical Representation)
#
# - To visually compare the **actual vs predicted labels**, we plot them side by side.
# - Each point represents a sample in the test dataset.
# - Black dots = **Actual Labels**
# - Blue crosses = **Predicted Labels**

# %%
plt.figure(figsize=(10,6))
plt.scatter(range(len(y_test)), y_test, color="black", label="Actual")
plt.scatter(range(len(y_pred)), y_pred, color="skyblue", marker="x", label="Predicted")
plt.xlabel("Sold")
plt.ylabel("Label (0=Not_sold, 1=Sold)")
plt.title("Actual vs Predicted Sold (XGBOOST Classifier)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Conclusion
#
# This notebook demonstrates a complete **XGBoost Classification pipeline** using the `car_sales_dataset`:
# - Data loading, exploration, and preprocessing (including scaling).
# - Splitting into training/testing sets for unbiased evaluation.
# - Model training using **XGBClassifier (Extreme Gradient Boosting)**.
# - Evaluation with **accuracy, precision, recall, F1-score, ROC-AUC, and confusion matrix**.
# - Visualization via confusion matrix heatmap and feature importance plots.
#
# ---
#
# ### 🔍 Key Findings
# - The XGBoost classifier achieved **~90.5% testing accuracy** and **~99.07% training accuracy**, indicating strong predictive performance with minimal overfitting.
# - The **confusion matrix** revealed that most instances were correctly classified, with only a small number of misclassifications.
# - Precision, recall, and F1-scores confirmed **balanced classification** performance across classes.
# - Feature importance analysis highlighted the most influential predictors, offering interpretability for decision-making.
#
# ---
#
# ### ✅ Recommendations Before Production Use
# 1. Perform **hyperparameter tuning** (e.g., `max_depth`, `learning_rate`, `subsample`, `colsample_bytree`, `gamma`) with GridSearchCV or RandomizedSearchCV to further enhance accuracy.
# 2. Apply **early stopping** and monitor validation sets to reduce chances of overfitting.
# 3. Use **class imbalance techniques** (`scale_pos_weight` or SMOTE) if dataset shows skewed class distributions.
# 4. Save the trained model using `joblib.dump()` or XGBoost’s native `.save_model()` for deployment.
# 5. Organize the repository with structured folders (`data/`, `notebooks/`, `models/`, `results/`) and include a `requirements.txt` file for reproducibility.
#
# ---
#
# # ✅ Final Conclusion
#
# In this project, we successfully implemented an **XGBoost Classifier** on the car sales dataset, covering the complete workflow from **data preprocessing to model evaluation and visualization**.
#
# #### 🔑 Highlights:
# - 📊 Achieved **90.5% test accuracy** and **99.07% training accuracy**, confirming strong predictive ability.
# - 🧪 Confusion matrix and classification report validated consistent classification with minimal errors.
# - 🔎 Feature importance analysis provided interpretability into key predictors driving the outcomes.
# - ⚡ Visualizations (confusion matrix heatmap, feature importance) gave clear insights into model performance and decision-making.
#
# #### 💡 Implications:
# XGBoost proved to be a **highly efficient and accurate algorithm** for this classification problem. With fine-tuned hyperparameters, class imbalance handling, and early stopping, its generalization can improve even further. This makes XGBoost an excellent choice for **business analytics, predictive modeling, and real-world decision-making applications**.
#
# ---
#
# > ✅ Overall, this project provides a **well-documented, reproducible, and high-performing XGBoost classification pipeline**, making it a strong addition to your machine learning GitHub portfolio.
